# %%
# !pip install pandas numpy matplotlib scikit-learn
# Out:
# ...
#   Using cached pandas-3.0.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp313-cp313-win_amd64.whl.metadata (116 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-12.1.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached scipy-1.17.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...

# %%
import pandas as pd

df = pd.read_csv("E:/data.csv")
df.head()
# Out:
#   Company        Date Close/Last    Volume     Open       High      Low
# 0    AAPL  07/17/2023    $193.99  50520160  $191.90    $194.32  $191.81
# 1    AAPL  07/14/2023    $190.69  41616240  $190.23  $191.1799  $189.63
# 2    AAPL  07/13/2023    $190.54  41342340  $190.50    $191.19  $189.78
# 3    AAPL  07-12-2023    $189.77  60750250  $189.68    $191.70  $188.47
# 4    AAPL  07-11-2023    $188.08  46638120  $189.16    $189.30  $186.60

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25160 entries, 0 to 25159
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Company     25160 non-null  str
#  1   Date        25160 non-null  str
#  2   Close/Last  25160 non-null  str
#  3   Volume      25160 non-null  int64
#  4   Open        25160 non-null  str
#  5   High        25160 non-null  str
#  6   Low         25160 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 1.3 MB
# Company       0
# Date          0
# Close/Last    0
# Volume        0
# Open          0
# High          0
# Low           0
# dtype: int64

# %%
df=df.dropna()
df.head()
# Out:
#   Company        Date Close/Last    Volume     Open       High      Low
# 0    AAPL  07/17/2023    $193.99  50520160  $191.90    $194.32  $191.81
# 1    AAPL  07/14/2023    $190.69  41616240  $190.23  $191.1799  $189.63
# 2    AAPL  07/13/2023    $190.54  41342340  $190.50    $191.19  $189.78
# 3    AAPL  07-12-2023    $189.77  60750250  $189.68    $191.70  $188.47
# 4    AAPL  07-11-2023    $188.08  46638120  $189.16    $189.30  $186.60
