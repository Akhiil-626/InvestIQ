# %%
import pandas as pd
import numpy as np

df = pd.read_csv("E:/data.csv")

# sort by time
df = df.sort_values('Date')

# set Date as index
df.set_index('Date', inplace=True)

print(df.head())
# Out:
#            Company Close/Last     Volume      Open      High       Low
# Date
# 01-02-2014    SBUX    $38.585    8487286   $39.035   $39.135  $38.5025
# 01-02-2014    QCOM     $73.32   10110170    $73.61    $73.77   $73.255
# 01-02-2014    AMZN   $19.8985   42756140    $19.94   $19.968   $19.701
# 01-02-2014     AMD      $3.95   20548430     $3.85     $3.98     $3.84
# 01-02-2014    AAPL   $19.7547  234645954  $19.8457  $19.8939   $19.715

# %%
# 80% train, 20% test
split_ratio = 0.8
split_index = int(len(df) * split_ratio)

train = df.iloc[:split_index]
test = df.iloc[split_index:]

print("Train size:", train.shape)
print("Test size:", test.shape)
# Out:
# Train size: (20128, 6)
# Test size: (5032, 6)

# %%
price_cols = ['Open', 'High', 'Low', 'Close/Last']

for col in price_cols:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace('$', '', regex=False)
        .astype(float)
    )

# %%
df['Volume'] = pd.to_numeric(df['Volume'], errors='coerce')
df.dropna(inplace=True)
print(df.dtypes)
# Out:
# Date           datetime64[us]
# Close/Last            float64
# Volume                  int64
# Open                  float64
# High                  float64
# Low                   float64
# Close_lag_1               str
# Close_lag_2               str
# Close_lag_3               str
# dtype: object

# %%
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 0.5967760640629498
# RMSE: 1.6572759156330696

# %%
# Predict on test data
y_pred = model.predict(X_test)

# Create a copy of corresponding rows
df_final = df.iloc[split_index:].copy()

# Add prediction column
df_final['Predicted_Close'] = y_pred

# %%
df_final.head()
# Out:
#            Date  Close/Last   Volume    Open     High     Low  Close_lag_1  \
# 5020 2013-02-08      37.115  9391634  36.750  37.1350  36.580       40.185
# 4978 2013-02-10      38.595  6088422  38.295  38.6150  38.105       37.115
# 4936 2013-02-12      40.535  5773100  40.745  40.8445  40.455       38.595
# 4999 2013-03-09      35.800  7249400  35.850  36.0700  35.595       40.535
# 4977 2013-03-10      38.435  8164122  38.480  38.7300  38.160       35.800
#
#       Close_lag_2  Close_lag_3  Predicted_Close
# 5020       38.580       36.740        36.940950
# 4978       40.185       38.580        38.414949
# 4936       37.115       40.185        40.616446
# 4999       38.595       37.115        35.841820
# 4977       40.535       38.595        38.438062

# %%
df_final.to_csv("preprocessed_with_predictions.csv", index=False)
